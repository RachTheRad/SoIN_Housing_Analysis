# %%
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")

# %%
#Import necessary libraries and such for project. And some extra stuff, just in case.
import pandas as pd
import matplotlib
from pandas import DataFrame
import matplotlib.pyplot as plt
import os
import random

# %%
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index=['a', 'b', 'c'])
df2 = pd.DataFrame({'C': [7, 8, 9], 'D': [10, 11, 12]}, index=['a', 'b', 'c'])
df3 = pd.DataFrame({'E': [13, 14, 15], 'F': [16, 17, 18]}, index=['a', 'b', 'c'])

# Join all three DataFrames based on their indices
result = df1.join([df2, df3])
print(result)
# Out:
#    A  B  C   D   E   F
# a  1  4  7  10  13  16
# b  2  5  8  11  14  17
# c  3  6  9  12  15  18

# %%
bartco_sqft = pd.read_csv('Data_Sources\med_sqft_bartco.csv')

#verify data reads in and print the first five rows)
bartco_sqft.head()

# %%
def process_data(bartco_sqft):
    # Read in the data for the Bartholomew County median square footage by listing
    bartco_sqft = pd.read_csv('Data_Sources\med_sqft_bartco.csv')
    
    # Define the data types 
    print (bartco_sqft.dtypes)

    # Drop unneccessary columns (YOY data)
    bcosqft_clean = bartco_sqft.drop(columns=['Median Pending Sqft Yoy (tooltip)', 'Median Pending Sqft Yoy'])
    
    return bcosqft_clean

# %%
housing_data= pd.read_csv('Data_Sources\county_market_tracker_clean.zip')
housing_data.head()

# %%
bartco_sqft = pd.read_csv('Data_Sources\med_sqft_bartco.csv')
claco_sqft = pd.read_csv('Data_Sources\med_sqft_claco.csv')

# %%
housing_data = pd.read_csv(os.path.join('Data_Sources\county_market_tracker_clean.zip'), 
                           usecols=['region', 
                                    'state', 
                                    'median_sale_price', 
                                    'median_list_price', 
                                    'median_ppsf'])

housing_data.head()

# %%
bartco_sqft.merge(claco_sqft)

# %%
# Write code below 💖


fact = random.randint(0,6)

if fact == 0:
  print("Flamingos turn pink from eating shrimp.")
elif fact == 1:
  print ("The only food that doesn\'t spoil is honey.")
elif fact == 2:
  print('Shrimp can only swim backwards.')
elif fact == 3:
  print("'A taste bud\'s life span is about 10 days.")
elif fact == 4:
  print("It is impossible to sneeze while sleeping.")
else:
  print("It is illegal to sing off-key in North Carolina.")
# Out:
# It is illegal to sing off-key in North Carolina.

# %%
for mean in DataFrame
    if DataFrame["Region"] == "Floyd Count, IN":
        then
