# %%
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")
# Out:
# Emil Refsnes
# Tobias Refsnes
# Linus Refsnes

# %%
#Import necessary libraries and such for project. And some extra stuff, just in case.
import pandas as pd
import matplotlib
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
bartco_sqft = pd.read_csv('Data_Sources\med_sqft_bartco.csv')

#verify data reads in and print the first five rows)
bartco_sqft.head()

# %% [markdown]
# Trying to create a function to read, display shape, dispaly data, and drop necessary columns

# %%
def clean_shape(bartco_sqft):
    #Function process to show head of data
    bartco_sqft['']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 def clean_shape(bartco_sqft):
#       2     pd.head()
# ----> 4 bartco_sqft
#
# NameError: name 'bartco_sqft' is not defined
