# %% [markdown]
# ## Data Dictionary
# ### Southern Indiana Housing and Public Education Analysis

# %% [markdown]
# County Market Tracker - [Source - Redfin Data Center](https://www.redfin.com/news/data-center/)
# |Field | Data Type | Description |
# |-------------|-----------|---------------------------------------|
# |period_begin |	Object | Beginning date data in this row was pulled from |
# |period_end	| Object | End date data in this row was pulled from |
# |table_id | Int64 | Table ID key |
# |region	| Object | Counties within the states from the USA |
# |state | Object | States from the USA |
# |state_code | Object | Numeric ID assigned to each state by Redfin |
# |property_type| Object | What kind of property was being sold (ex: Condo/Co-op, Townhouse, Single Family Residential, etc.) |
# |property_type_id | Int64 |	Numeric code given to the property type (assuming by Redfin) |
# |median_sale_price | Float64 | The median sale price for this county for the property type listed on the same row for the region listed. |
# |median_list_price | Float64 |The median list price for this county for the property type listed on the same row for the region listed.
# |median_ppsf | Float64 | Median price per square foot for property sold. |
# |median_ppsf_yoy | Float64 | Median price per square foot for property sold for year over year. |
# |median_list_ppsf |	Float64 |Median list price per square foot for property sold. |
# |median_list_ppsf_yoy |	Float64 | Median lsit price per square foot for property sold year over year. |
# |inventory | Float64 | Number of real estate listings available. |
# |inventory_yoy | Float64 | Inventory change year over year, listed as a percentage point. |
# |sold_above_list | Float64 | Properties that sold above list price. |
# |parent_metro_region | Objcet | Closest metro region. If there is no close metro region it is stated as "[State] nonmetropolitan area." |
# |parent_metro_region_metro_code | Float64 | Numeric ID assigned to the parent metro region. |
# |last_updated | Object | Date the data was last updated. |

# %% [markdown]
# ILEARN 2024 ELA Scores for Grade 3 for Indiana by School Corporation - [Source](https://www.in.gov/doe/it/data-center-and-reports/)
# |Field | Data Type | Description |
# |-------------|-----------|---------------------------------------|
# |Data Notes / Corp ID' | Object | Corporation ID provided by the state of Indiana |
# |Unnamed: 1 / Corp Name' | Object | The name of the school corporation |
# |Unnamed: 2 / ELA Below Proficiency | Object | Students in Grade 3 below proficiency for ELA |
# |Unnamed: 3 / ELA Approaching Proficiency | Object | Students approaching proficiency in ELA in Grade 3 |
# |Unnamed: 4 / ELA At Proficiency | Object | Number of students at proficiency in ELA for Grade 3|
# |Unnamed: 5 / ELA Above Proficiency | Object | Number of students above proficiency at Grade 3 |
# |Unnamed: 6 / ELA Total Proficient | Object | Total number of students considered proficient in ELA |
# |Unnamed: 7 / ELA Total Tested | Object | Total number of students tested |
# |Unnamed: 8 / ELA Proficient % | Object | Percentage of students proficient |

# %% [markdown]
# ILEARN 2024 Math Scores for Grade 3 for Indiana by School Corporation - [Source](https://www.in.gov/doe/it/data-center-and-reports/)
# |Field | Data Type | Description |
# |-------------|-----------|---------------------------------------|
# |Data Notes / Corp ID' | Object | Corporation ID provided by the state of Indiana |
# |Unnamed: 1 / Corp Name' | Object | The name of the school corporation |
# |Unnamed: 2 / Math Below Proficiency | Object | Students in Grade 3 below proficiency for Math |
# |Unnamed: 3 / Math Approaching Proficiency | Object | Students approaching proficiency in Math in Grade 3 |
# |Unnamed: 4 / Math At Proficiency | Object | Number of students at proficiency in Math for Grade 3|
# |Unnamed: 5 / Math Above Proficiency | Object | Number of students above proficiency at Grade 3 |
# |Unnamed: 6 / Math Total Proficient | Object | Total number of students considered proficient in Math |
# |Unnamed: 7 / Math Total Tested | Object | Total number of students tested |
# |Unnamed: 8 / Math Proficient % | Object | Percentage of students proficient |

# %% [markdown]
# ILEARN 2024 Science Scores for Grade 3 for Indiana by School Corporation - [Source](https://www.in.gov/doe/it/data-center-and-reports/)
# |Field | Data Type | Description |
# |-------------|-----------|---------------------------------------|
# |Data Notes / Corp ID' | Object | Corporation ID provided by the state of Indiana |
# |Unnamed: 1 / Corp Name' | Object | The name of the school corporation |
# |Unnamed: 2 / Science Below Proficiency | Object | Students in Grade 3 below proficiency for Science |
# |Unnamed: 3 / Science Approaching Proficiency | Object | Students approaching proficiency in Science in Grade 3 |
# |Unnamed: 4 / Science At Proficiency | Object | Number of students at proficiency in Science for Grade 3|
# |Unnamed: 5 / Science Above Proficiency | Object | Number of students above proficiency at Grade 3 |
# |Unnamed: 6 / Science Total Proficient | Object | Total number of students considered proficient in Science |
# |Unnamed: 7 / Science Total Tested | Object | Total number of students tested |
# |Unnamed: 8 / Science Proficient % | Object | Percentage of students proficient |

# %% [markdown]
# ILEARN 20Social Studies Scores for Grade 5 for Indiana by School Corporation - [Source](https://www.in.gov/doe/it/data-center-and-reports/)
# |Field | Data Type | Description |
# |-------------|-----------|---------------------------------------|
# |Data Notes / Corp ID' | Object | Corporation ID provided by the state of Indiana |
# |Unnamed: 1 / Corp Name' | Object | The name of the school corporation |
# |Unnamed: 2 / Social Studies Below Proficiency | Object | Students in Grade 3 below proficiency for Social Studies |
# |Unnamed: 3 / Social Studies Approaching Proficiency | Object | Students approaching proficiency in Social Studies in Grade 5 |
# |Unnamed: 4 / Social Studies At Proficiency | Object | Number of students at proficiency in Social Studies for Grade 5|
# |Unnamed: 5 / Social Studies Above Proficiency | Object | Number of students above proficiency at Grade 5 |
# |Unnamed: 6 / Social Studies Total Proficient | Object | Total number of students considered proficient in Social Studies |
# |Unnamed: 7 / Social Studies Total Tested | Object | Total number of students tested |
# |Unnamed: 8 /Social Studies Proficient % | Object | Percentage of students proficient |
