# %%
#Import necessary libraries and such for project. And some extra stuff, just in case.
import pandas as pd
import matplotlib
from pandas import DataFrame
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
import datetime
import seaborn as sns
import dash # add this to the top!
from dash import dcc

# %%
  import plotly.express as px

# %% [markdown]
# ### Median Square Footage of Houses listed by County
#
# #### Bartholomew County, IN

# %%
#read in the data for median square footage by county starting with Bartholomew County, IN 

bartco_sqft = pd.read_csv('Data_Sources\med_sqft_bartco.csv')

#verify data reads in and print the first five rows)
bartco_sqft.head()
# Out:
#    Day of Year  Year of Period End Period Begin Period End  \
# 0            1                2023    12/5/2022   1/1/2023
# 1            2                2022    12/6/2021   1/2/2022
# 2            5                2025    12/9/2024   1/5/2025
# 3            7                2024   12/11/2023   1/7/2024
# 4            8                2023   12/12/2022   1/8/2023
#
#   Median Pending Sqft Yoy (tooltip) Median Pending Sqft Yoy  \
# 0                           -10.90%                    -11%
# 1                             8.30%                      8%
# 2                             9.90%                     10%
# 3                           -18.80%                    -19%
# 4                             5.90%                      6%
#
#   Median Pending Sqft
# 0            1,802.10
# 1               2,023
# 2            1,771.70
# 3            1,612.10
# 4            1,986.10

# %%
# Let's see the shape of the dataset/dataframe 
bsqftco = bartco_sqft.shape
print(f'The DataFrame has {bsqftco[0]} rows and {bsqftco[1]} columns! \n')

#looking at the dataframe
bartco_sqft.dtypes
# Out:
# The DataFrame has 163 rows and 7 columns!
# Day of Year                           int64
# Year of Period End                    int64
# Period Begin                         object
# Period End                           object
# Median Pending Sqft Yoy (tooltip)    object
# Median Pending Sqft Yoy              object
# Median Pending Sqft                  object
# dtype: object

# %%
# I don't need the YOY information, I'm not looking at patterns, just a current snapshot. 
# Removing those two columns
bcosqft_clean = bartco_sqft.drop(columns=['Median Pending Sqft Yoy (tooltip)', 'Median Pending Sqft Yoy'])

bcosqft_clean
# Out:
#      Day of Year  Year of Period End Period Begin  Period End  \
# 0              1                2023    12/5/2022    1/1/2023
# 1              2                2022    12/6/2021    1/2/2022
# 2              5                2025    12/9/2024    1/5/2025
# 3              7                2024   12/11/2023    1/7/2024
# 4              8                2023   12/12/2022    1/8/2023
# ..           ...                 ...          ...         ...
# 158          357                2024   11/25/2024  12/22/2024
# 159          358                2023   11/27/2023  12/24/2023
# 160          359                2022   11/28/2022  12/25/2022
# 161          364                2024    12/2/2024  12/29/2024
# 162          365                2023    12/4/2023  12/31/2023
#
#     Median Pending Sqft
# 0              1,802.10
# 1                 2,023
# 2              1,771.70
# 3              1,612.10
# 4              1,986.10
# ..                  ...
# 158            1,972.10
# ...

# %% [markdown]
# I'll need to clean the data for each one.
# And then will I be able to join the square footage with the pricing using day of year?

# %% [markdown]
# #### Floyd County, IN

# %%
#read in the data for median square footage by county - Floyd County, IN

floco_sqft = pd.read_csv('Data_Sources\med_sqft_floco.csv')

#verify data reads in and print the first five rows)
floco_sqft.head()
# Out:
#    Day of Year  Year of Period End Period Begin Period End  \
# 0            1                2023    12/5/2022   1/1/2023
# 1            2                2022    12/6/2021   1/2/2022
# 2            5                2025    12/9/2024   1/5/2025
# 3            7                2024   12/11/2023   1/7/2024
# 4            8                2023   12/12/2022   1/8/2023
#
#   Median Pending Sqft Yoy (tooltip) Median Pending Sqft Yoy  \
# 0                           -22.00%                    -22%
# 1                             8.50%                      9%
# 2                           -13.00%                    -13%
# 3                            23.70%                     24%
# 4                           -15.50%                    -16%
#
#   Median Pending Sqft
# 0            1,535.70
# 1            1,969.80
# 2            1,742.20
# 3            2,002.70
# 4            1,619.50

# %%
# Let's see the shape of the dataset/dataframe 
fsqftco = floco_sqft.shape
print(f'The DataFrame has {fsqftco[0]} rows and {fsqftco[1]} columns! \n')

#looking at the data types in each column
floco_sqft.dtypes
# Out:
# The DataFrame has 163 rows and 7 columns!
# Day of Year                           int64
# Year of Period End                    int64
# Period Begin                         object
# Period End                           object
# Median Pending Sqft Yoy (tooltip)    object
# Median Pending Sqft Yoy              object
# Median Pending Sqft                  object
# dtype: object

# %%
# Removing the YOY columns
flcosqft_clean = floco_sqft.drop(columns=['Median Pending Sqft Yoy (tooltip)', 'Median Pending Sqft Yoy'])

flcosqft_clean
# Out:
#      Day of Year  Year of Period End Period Begin  Period End  \
# 0              1                2023    12/5/2022    1/1/2023
# 1              2                2022    12/6/2021    1/2/2022
# 2              5                2025    12/9/2024    1/5/2025
# 3              7                2024   12/11/2023    1/7/2024
# 4              8                2023   12/12/2022    1/8/2023
# ..           ...                 ...          ...         ...
# 158          357                2024   11/25/2024  12/22/2024
# 159          358                2023   11/27/2023  12/24/2023
# 160          359                2022   11/28/2022  12/25/2022
# 161          364                2024    12/2/2024  12/29/2024
# 162          365                2023    12/4/2023  12/31/2023
#
#     Median Pending Sqft
# 0              1,535.70
# 1              1,969.80
# 2              1,742.20
# 3              2,002.70
# 4              1,619.50
# ..                  ...
# 158            1,871.20
# ...

# %% [markdown]
# #### Clark County, IN

# %%
#read in the data for median square footage by county - Clark County, IN

claco_sqft = pd.read_csv('Data_Sources\med_sqft_claco.csv')

#verify data reads in and print the first five rows)
claco_sqft.head()
# Out:
#    Day of Year  Year of Period End Period Begin Period End  \
# 0            1                2023    12/5/2022   1/1/2023
# 1            2                2022    12/6/2021   1/2/2022
# 2            5                2025    12/9/2024   1/5/2025
# 3            7                2024   12/11/2023   1/7/2024
# 4            8                2023   12/12/2022   1/8/2023
#
#   Median Pending Sqft Yoy (tooltip) Median Pending Sqft Yoy  \
# 0                             9.00%                      9%
# 1                             6.30%                      6%
# 2                             3.30%                      3%
# 3                            -7.30%                     -7%
# 4                            -1.90%                     -2%
#
#   Median Pending Sqft
# 0               1,771
# 1            1,625.10
# 2               1,526
# 3            1,477.30
# 4            1,593.70

# %%
# Let's see the shape of the dataset/dataframe 
csqftco = claco_sqft.shape
print(f'The DataFrame has {csqftco[0]} rows and {csqftco[1]} columns! \n')

#looking at the data types in each column
claco_sqft.dtypes
# Out:
# The DataFrame has 163 rows and 7 columns!
# Day of Year                           int64
# Year of Period End                    int64
# Period Begin                         object
# Period End                           object
# Median Pending Sqft Yoy (tooltip)    object
# Median Pending Sqft Yoy              object
# Median Pending Sqft                  object
# dtype: object

# %%
# Removing the YOY columns
clcosqft_clean = claco_sqft.drop(columns=['Median Pending Sqft Yoy (tooltip)', 'Median Pending Sqft Yoy'])

clcosqft_clean
# Out:
#      Day of Year  Year of Period End Period Begin  Period End  \
# 0              1                2023    12/5/2022    1/1/2023
# 1              2                2022    12/6/2021    1/2/2022
# 2              5                2025    12/9/2024    1/5/2025
# 3              7                2024   12/11/2023    1/7/2024
# 4              8                2023   12/12/2022    1/8/2023
# ..           ...                 ...          ...         ...
# 158          357                2024   11/25/2024  12/22/2024
# 159          358                2023   11/27/2023  12/24/2023
# 160          359                2022   11/28/2022  12/25/2022
# 161          364                2024    12/2/2024  12/29/2024
# 162          365                2023    12/4/2023  12/31/2023
#
#     Median Pending Sqft
# 0                 1,771
# 1              1,625.10
# 2                 1,526
# 3              1,477.30
# 4              1,593.70
# ..                  ...
# 158               1,508
# ...

# %% [markdown]
# ### Median Listed Housing Prices by County
#
# #### Bartholomew County Median Listed Housing Prices

# %%
#read in the data for median listed housing prices by county - Bartholomew County, IN
bartco_price = pd.read_csv('Data_Sources\med_price_bartco.csv')

#verify data reads in and print the first five rows)
bartco_price.head()
# Out:
#    Day of Year     Last Updated  Year of Period End Period Begin Period End  \
# 0            1  2/12/2025 14:46                2023    12/5/2022   1/1/2023
# 1            2  2/12/2025 14:46                2022    12/6/2021   1/2/2022
# 2            5  2/12/2025 14:46                2025    12/9/2024   1/5/2025
# 3            7  2/12/2025 14:46                2024   12/11/2023   1/7/2024
# 4            8  2/12/2025 14:46                2023   12/12/2022   1/8/2023
#
#   Median Sale Price Yoy (tooltip)  Median Sale Price Yoy Median Sale Price
# 0                          -2.89%              -0.028948        227,687.50
# 1                          14.94%               0.149387           234,475
# 2                          -1.58%              -0.015849        247,562.50
# 3                           5.84%               0.058375        251,549.30
# 4                           3.29%               0.032920           237,675

# %%
# shape and data types
bprice = bartco_price.shape
print(f'The DataFrame has {bprice[0]} rows and {bprice[1]} columns! \n')

#looking at the data types in each column
bartco_price.dtypes
# Out:
# The DataFrame has 163 rows and 8 columns!
# Day of Year                          int64
# Last Updated                        object
# Year of Period End                   int64
# Period Begin                        object
# Period End                          object
# Median Sale Price Yoy (tooltip)     object
# Median Sale Price Yoy              float64
# Median Sale Price                   object
# dtype: object

# %%
# Removing the YOY columns
bprice_clean = bartco_price.drop(columns=['Median Sale Price Yoy (tooltip)', 'Median Sale Price Yoy'])

bprice_clean
# Out:
#      Day of Year     Last Updated  Year of Period End Period Begin  \
# 0              1  2/12/2025 14:46                2023    12/5/2022
# 1              2  2/12/2025 14:46                2022    12/6/2021
# 2              5  2/12/2025 14:46                2025    12/9/2024
# 3              7  2/12/2025 14:46                2024   12/11/2023
# 4              8  2/12/2025 14:46                2023   12/12/2022
# ..           ...              ...                 ...          ...
# 158          357  2/12/2025 14:46                2024   11/25/2024
# 159          358  2/12/2025 14:46                2023   11/27/2023
# 160          359  2/12/2025 14:46                2022   11/28/2022
# 161          364  2/12/2025 14:46                2024    12/2/2024
# 162          365  2/12/2025 14:46                2023    12/4/2023
#
#      Period End Median Sale Price
# 0      1/1/2023        227,687.50
# 1      1/2/2022           234,475
# 2      1/5/2025        247,562.50
# ...

# %%
#read in the data for median listed housing prices by county - Clark County, IN

claco_price = pd.read_csv('Data_Sources\med_price_clark.csv')

#verify data reads in and print the first five rows)
claco_price.head()
# Out:
#    Day of Year    Last Updated  Year of Period End Period Begin Period End  \
# 0            1  2/5/2025 14:47                2023    12/5/2022   1/1/2023
# 1            2  2/5/2025 14:47                2022    12/6/2021   1/2/2022
# 2            5  2/5/2025 14:47                2025    12/9/2024   1/5/2025
# 3            7  2/5/2025 14:47                2024   12/11/2023   1/7/2024
# 4            8  2/5/2025 14:47                2023   12/12/2022   1/8/2023
#
#   Median Sale Price Yoy (tooltip)  Median Sale Price Yoy Median Sale Price
# 0                           2.94%               0.029364        229,023.70
# 1                          13.41%               0.134071        222,490.50
# 2                          -3.95%              -0.039493           227,735
# 3                           0.50%               0.004980        237,098.70
# 4                           7.42%               0.074197        235,923.70

# %%
# shape and data types
cprice = claco_price.shape
print(f'The DataFrame has {cprice[0]} rows and {cprice[1]} columns! \n')

#looking at the data types in each column
claco_price.dtypes
# Out:
# The DataFrame has 162 rows and 8 columns!
# Day of Year                          int64
# Last Updated                        object
# Year of Period End                   int64
# Period Begin                        object
# Period End                          object
# Median Sale Price Yoy (tooltip)     object
# Median Sale Price Yoy              float64
# Median Sale Price                   object
# dtype: object

# %% [markdown]
# Again, I don't need any YOY data. I'll be dropping those columns.

# %%
# Removing the YOY columns
cprice_clean = claco_price.drop(columns=['Median Sale Price Yoy (tooltip)', 'Median Sale Price Yoy'])

cprice_clean
# Out:
#      Day of Year    Last Updated  Year of Period End Period Begin  Period End  \
# 0              1  2/5/2025 14:47                2023    12/5/2022    1/1/2023
# 1              2  2/5/2025 14:47                2022    12/6/2021    1/2/2022
# 2              5  2/5/2025 14:47                2025    12/9/2024    1/5/2025
# 3              7  2/5/2025 14:47                2024   12/11/2023    1/7/2024
# 4              8  2/5/2025 14:47                2023   12/12/2022    1/8/2023
# ..           ...             ...                 ...          ...         ...
# 157          357  2/5/2025 14:47                2024   11/25/2024  12/22/2024
# 158          358  2/5/2025 14:47                2023   11/27/2023  12/24/2023
# 159          359  2/5/2025 14:47                2022   11/28/2022  12/25/2022
# 160          364  2/5/2025 14:47                2024    12/2/2024  12/29/2024
# 161          365  2/5/2025 14:47                2023    12/4/2023  12/31/2023
#
#     Median Sale Price
# ...

# %%
#read in the data for median listed housing prices by county - Floyd County, IN
floco_price = pd.read_csv('Data_Sources\med_price_floco.csv')

#verify data reads in and print the first five rows)
floco_price.head()
# Out:
#    Day of Year     Last Updated  Year of Period End Period Begin Period End  \
# 0            1  2/12/2025 14:46                2023    12/5/2022   1/1/2023
# 1            2  2/12/2025 14:46                2022    12/6/2021   1/2/2022
# 2            5  2/12/2025 14:46                2025    12/9/2024   1/5/2025
# 3            7  2/12/2025 14:46                2024   12/11/2023   1/7/2024
# 4            8  2/12/2025 14:46                2023   12/12/2022   1/8/2023
#
#   Median Sale Price Yoy (tooltip)  Median Sale Price Yoy Median Sale Price
# 0                         -10.69%              -0.106938           219,950
# 1                          21.05%               0.210519        246,287.50
# 2                          33.33%               0.333254        315,981.20
# 3                          -2.18%              -0.021823           237,000
# 4                           3.50%               0.035030        242,287.50

# %%
# shape and data types
fprice = floco_price.shape
print(f'The DataFrame has {fprice[0]} rows and {fprice[1]} columns! \n')

#looking at the data types in each column
floco_price.dtypes
# Out:
# The DataFrame has 163 rows and 8 columns!
# Day of Year                          int64
# Last Updated                        object
# Year of Period End                   int64
# Period Begin                        object
# Period End                          object
# Median Sale Price Yoy (tooltip)     object
# Median Sale Price Yoy              float64
# Median Sale Price                   object
# dtype: object

# %%
# Removing the YOY columns
fprice_clean = floco_price.drop(columns=['Median Sale Price Yoy (tooltip)', 'Median Sale Price Yoy'])

fprice_clean
# Out:
#      Day of Year     Last Updated  Year of Period End Period Begin  \
# 0              1  2/12/2025 14:46                2023    12/5/2022
# 1              2  2/12/2025 14:46                2022    12/6/2021
# 2              5  2/12/2025 14:46                2025    12/9/2024
# 3              7  2/12/2025 14:46                2024   12/11/2023
# 4              8  2/12/2025 14:46                2023   12/12/2022
# ..           ...              ...                 ...          ...
# 158          357  2/12/2025 14:46                2024   11/25/2024
# 159          358  2/12/2025 14:46                2023   11/27/2023
# 160          359  2/12/2025 14:46                2022   11/28/2022
# 161          364  2/12/2025 14:46                2024    12/2/2024
# 162          365  2/12/2025 14:46                2023    12/4/2023
#
#      Period End Median Sale Price
# 0      1/1/2023           219,950
# 1      1/2/2022        246,287.50
# 2      1/5/2025        315,981.20
# ...

# %% [markdown]
# ### ILEARN Scores for all schoool corporations in Indiana - ELA Section

# %%
#read in the data for ILEARN 2024 test scores for all school coporations in Indiana - ELA section
ilearn_ELA_corp = pd.read_csv('Data_Sources\ILEARN_Corp_ELA.csv')

#verify data reads in and print the first five rows)
ilearn_ELA_corp.head()
# Out:
#                                          Data Notes:  \
# 0      Scores reflect all ILEARN Spring 2024 testers
# 1  *** - Indicates less than 10 students in group...
# 2                                                NaN
# 3                                            Corp ID
# 4                                               0015
#
#                         Unnamed: 1               Unnamed: 2  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                  Grade 3
# 3                        Corp Name  ELA\nBelow\nProficiency
# 4  Adams Central Community Schools                       35
#
#                        Unnamed: 3             Unnamed: 4  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# ...

# %%
# will replace Nan value in dataframe with value 1
ela_copy = ilearn_ELA_corp.replace(to_replace = np.nan, value = 1)

for x in ela_copy.index:
    if ela_copy.loc[x, "Unnamed: 1"] == 1:
        ela_copy.drop(x, inplace=True)
ela_copy
# Out:
#     Data Notes:                        Unnamed: 1               Unnamed: 2  \
# 3       Corp ID                         Corp Name  ELA\nBelow\nProficiency
# 4          0015   Adams Central Community Schools                       35
# 5          0025     North Adams Community Schools                       51
# 6          0035               South Adams Schools                       29
# 7          0125  MSD Southwest Allen County Schls                      135
# ..          ...                               ...                      ...
# 389        9970           ACE Preparatory Academy                       10
# 390        9975        Global Preparatory Academy                       62
# 391        9980                Steel City Academy                       20
# 392        9985       Seven Oaks Classical School                        5
# 393        9990   Higher Institute of Arts & Tech                       20
#
#                          Unnamed: 3             Unnamed: 4  \
# ...

# %%
#find out datatype for Column 'Unnamed: 1'
print(ela_copy.dtypes)

#this is stupid. Let's rename the columns
# Renaming columns
ela_copy.rename(columns={'Data Notes': 'Corp ID', 
                         'Unnamed: 1': 'Corp Name', 
                         'Unnamed: 2': 'ELA Below Proficiency', 
                         'Unnamed: 3': 'ELA Approaching Proficiency', 
                         'Unnamed: 4': 'ELA At Proficiency',
                         'Unnamed: 5': 'ELA Above Proficiency',
                         'Unnamed: 6': 'ELA Total Proficient',
                         'Unnamed: 7': 'ELA Total Tested',
                         'Unnamed: 8': 'ELA Proficient %',
                         }
                         , inplace=True)
print(ela_copy)
# Out:
# Data Notes:     object
# Unnamed: 1      object
# Unnamed: 2      object
# Unnamed: 3      object
# Unnamed: 4      object
# Unnamed: 5      object
# Unnamed: 6      object
# Unnamed: 7      object
# Unnamed: 8      object
# Unnamed: 9      object
# Unnamed: 10     object
# Unnamed: 11     object
# Unnamed: 12     object
# Unnamed: 13     object
# Unnamed: 14     object
# Unnamed: 15     object
# Unnamed: 16     object
# Unnamed: 17     object
# Unnamed: 18     object
# Unnamed: 19     object
# Unnamed: 20     object
# Unnamed: 21     object
# Unnamed: 22     object
# Unnamed: 23     object
# Unnamed: 24     object
# Unnamed: 25     object
# Unnamed: 26     object
# Unnamed: 27     object
# Unnamed: 28     object
# Unnamed: 29     object
# Unnamed: 30     object
# Unnamed: 31     object
# Unnamed: 32     object
# Unnamed: 33     object
# Unnamed: 34     object
# Unnamed: 35     object
# Unnamed: 36     object
# Unnamed: 37     object
# Unnamed: 38     object
# Unnamed: 39     object
# ...

# %%
ela_copy = ela_copy.drop(ela_copy.iloc[:, 10:52], axis=1)
ela_copy
# Out:
#     Data Notes:                         Corp Name    ELA Below Proficiency  \
# 3       Corp ID                         Corp Name  ELA\nBelow\nProficiency
# 4          0015   Adams Central Community Schools                       35
# 5          0025     North Adams Community Schools                       51
# 6          0035               South Adams Schools                       29
# 7          0125  MSD Southwest Allen County Schls                      135
# ..          ...                               ...                      ...
# 389        9970           ACE Preparatory Academy                       10
# 390        9975        Global Preparatory Academy                       62
# 391        9980                Steel City Academy                       20
# 392        9985       Seven Oaks Classical School                        5
# 393        9990   Higher Institute of Arts & Tech                       20
#
#         ELA Approaching Proficiency     ELA At Proficiency  \
# ...

# %%
#rinse and repeat for the other sections of the ILEARN - Math, Science, Social Studies
# First - Math
ilearn_Math_corp = pd.read_csv('Data_Sources\ILEARN_Corp_Math.csv')

# %%
#let's check out the shape and size of these dfs

ilearnMath = ilearn_Math_corp.shape
print(f'The DataFrame has {ilearnMath[0]} rows and {ilearnMath[1]} columns! \n')
# Out:
# The DataFrame has 394 rows and 52 columns!

# %%
#looking at the first five rows because I know there are NaN values....

ilearn_Math_corp.head(5)
# Out:
#                                          Data Notes:  \
# 0      Scores reflect all ILEARN Spring 2024 testers
# 1  *** - Indicates less than 10 students in group...
# 2                                                NaN
# 3                                            Corp ID
# 4                                               0015
#
#                         Unnamed: 1                Unnamed: 2  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                   Grade 3
# 3                        Corp Name  Math\nBelow\nProficiency
# 4  Adams Central Community Schools                        16
#
#                         Unnamed: 3              Unnamed: 4  \
# 0                              NaN                     NaN
# 1                              NaN                     NaN
# 2                              NaN                     NaN
# ...

# %%
# will replace Nan value in dataframe with value 1
math_copy = ilearn_Math_corp.replace(to_replace = np.nan, value = 1)

# %%
for x in math_copy.index:
    if math_copy.loc[x, "Unnamed: 1"] == 1:
        math_copy.drop(x, inplace=True)
math_copy
# Out:
#     Data Notes:                        Unnamed: 1                Unnamed: 2  \
# 3       Corp ID                         Corp Name  Math\nBelow\nProficiency
# 4          0015   Adams Central Community Schools                        16
# 5          0025     North Adams Community Schools                        28
# 6          0035               South Adams Schools                        20
# 7          0125  MSD Southwest Allen County Schls                        91
# ..          ...                               ...                       ...
# 389        9970           ACE Preparatory Academy                         7
# 390        9975        Global Preparatory Academy                        54
# 391        9980                Steel City Academy                        20
# 392        9985       Seven Oaks Classical School                         2
# 393        9990   Higher Institute of Arts & Tech                        20
#
# ...

# %%
#this is stupid. Let's rename the columns
# Renaming columns
math_copy.rename(columns={'Data Notes': 'Corp ID', 
                         'Unnamed: 1': 'Corp Name', 
                         'Unnamed: 2': 'Math Below Proficiency', 
                         'Unnamed: 3': 'Math Approaching Proficiency', 
                         'Unnamed: 4': 'Math At Proficiency',
                         'Unnamed: 5': 'Math Above Proficiency',
                         'Unnamed: 6': 'Math Total Proficient',
                         'Unnamed: 7': 'Math Total Tested',
                         'Unnamed: 8': 'Math Proficient %',
                         }
                         , inplace=True)
print(math_copy)
# Out:
#     Data Notes:                         Corp Name    Math Below Proficiency  \
# 3       Corp ID                         Corp Name  Math\nBelow\nProficiency
# 4          0015   Adams Central Community Schools                        16
# 5          0025     North Adams Community Schools                        28
# 6          0035               South Adams Schools                        20
# 7          0125  MSD Southwest Allen County Schls                        91
# ..          ...                               ...                       ...
# 389        9970           ACE Preparatory Academy                         7
# 390        9975        Global Preparatory Academy                        54
# 391        9980                Steel City Academy                        20
# 392        9985       Seven Oaks Classical School                         2
# 393        9990   Higher Institute of Arts & Tech                        20
#
# ...

# %%
#dropping the columns that aren't for Grade 3
math_copy = math_copy.drop(math_copy.iloc[:, 10:52], axis=1)
math_copy
# Out:
#     Data Notes:                         Corp Name    Math Below Proficiency  \
# 3       Corp ID                         Corp Name  Math\nBelow\nProficiency
# 4          0015   Adams Central Community Schools                        16
# 5          0025     North Adams Community Schools                        28
# 6          0035               South Adams Schools                        20
# 7          0125  MSD Southwest Allen County Schls                        91
# ..          ...                               ...                       ...
# 389        9970           ACE Preparatory Academy                         7
# 390        9975        Global Preparatory Academy                        54
# 391        9980                Steel City Academy                        20
# 392        9985       Seven Oaks Classical School                         2
# 393        9990   Higher Institute of Arts & Tech                        20
#
# ...

# %%
# read in science data
ilearn_Science_corp = pd.read_csv('Data_Sources\ILEARN_Corp_Science.csv')

ilearn_Science_corp.head(5)
# Out:
#                                          Data Notes:  \
# 0      Scores reflect all ILEARN Spring 2024 testers
# 1  *** - Indicates less than 10 students in group...
# 2                                                NaN
# 3                                            Corp ID
# 4                                               0015
#
#                         Unnamed: 1                   Unnamed: 2  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                      Grade 4
# 3                        Corp Name  Science\nBelow\nProficiency
# 4  Adams Central Community Schools                           11
#
#                            Unnamed: 3                 Unnamed: 4  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# ...

# %%
# will replace Nan value in dataframe with value 1
sci_copy = ilearn_Science_corp.replace(to_replace = np.nan, value = 1)

for x in sci_copy.index:
    if sci_copy.loc[x, "Unnamed: 1"] == 1:
        sci_copy.drop(x, inplace=True)
sci_copy
# Out:
#     Data Notes:                        Unnamed: 1  \
# 3       Corp ID                         Corp Name
# 4          0015   Adams Central Community Schools
# 5          0025     North Adams Community Schools
# 6          0035               South Adams Schools
# 7          0125  MSD Southwest Allen County Schls
# ..          ...                               ...
# 383        9970           ACE Preparatory Academy
# 384        9975        Global Preparatory Academy
# 385        9980                Steel City Academy
# 386        9985       Seven Oaks Classical School
# 387        9990   Higher Institute of Arts & Tech
#
#                       Unnamed: 2                          Unnamed: 3  \
# 3    Science\nBelow\nProficiency  Science \nApproaching\nProficiency
# 4                             11                                  42
# 5                             17                                  36
# 6                             17                                  48
# ...

# %%
#this is stupid. Let's rename the columns
# Renaming columns
sci_copy.rename(columns={'Data Notes:': 'Corp ID', 
                         'Unnamed: 1': 'Corp Name', 
                         'Unnamed: 2': 'Science Below Proficiency', 
                         'Unnamed: 3': 'Science Approaching Proficiency', 
                         'Unnamed: 4': 'Science At Proficiency',
                         'Unnamed: 5': 'Science Above Proficiency',
                         'Unnamed: 6': 'Science Total Proficient',
                         'Unnamed: 7': 'Science Total Tested',
                         'Unnamed: 8': 'Science Proficient %',
                         }
                         , inplace=True)
display(sci_copy)
# Out:
#      Corp ID                         Corp Name    Science Below Proficiency  \
# 3    Corp ID                         Corp Name  Science\nBelow\nProficiency
# 4       0015   Adams Central Community Schools                           11
# 5       0025     North Adams Community Schools                           17
# 6       0035               South Adams Schools                           17
# 7       0125  MSD Southwest Allen County Schls                           65
# ..       ...                               ...                          ...
# 383     9970           ACE Preparatory Academy                            2
# 384     9975        Global Preparatory Academy                           18
# 385     9980                Steel City Academy                            8
# 386     9985       Seven Oaks Classical School                            0
# 387     9990   Higher Institute of Arts & Tech                           12
#
# ...

# %%
#dropping the columns that aren't for Grade 3
sci_copy = sci_copy.drop(sci_copy.iloc[:, 10:52], axis=1)
sci_copy
# Out:
#      Corp ID                         Corp Name    Science Below Proficiency  \
# 3    Corp ID                         Corp Name  Science\nBelow\nProficiency
# 4       0015   Adams Central Community Schools                           11
# 5       0025     North Adams Community Schools                           17
# 6       0035               South Adams Schools                           17
# 7       0125  MSD Southwest Allen County Schls                           65
# ..       ...                               ...                          ...
# 383     9970           ACE Preparatory Academy                            2
# 384     9975        Global Preparatory Academy                           18
# 385     9980                Steel City Academy                            8
# 386     9985       Seven Oaks Classical School                            0
# 387     9990   Higher Institute of Arts & Tech                           12
#
# ...

# %%
#read in social studies dataset
ilearn_Soc_corp = pd.read_csv('Data_Sources\ILEARN_Corp_SocSt.csv')

#look at first five rows and confirm there are NaN values in the top two rows
ilearn_Soc_corp.head(15)

#annnnnd they only test Grade 5 for social studies. Do I care about having a child well versed in civics? And that means we only have 10 columns. Yay?
# Out:
#                                           Data Notes:  \
# 0       Scores reflect all ILEARN Spring 2024 testers
# 1   *** - Indicates less than 10 students in group...
# 2                                                 NaN
# 3                                             Corp ID
# 4                                                0015
# 5                                                0025
# 6                                                0035
# 7                                                0125
# 8                                                0225
# 9                                                0235
# 10                                               0255
# 11                                               0365
# 12                                               0370
# 13                                               0395
# 14                                               0515
#
#                           Unnamed: 1                          Unnamed: 2  \
# ...

# %%
# will replace Nan value in dataframe with value 1
soc_copy = ilearn_Soc_corp.replace(to_replace = np.nan, value = 1)

for x in soc_copy.index:
    if soc_copy.loc[x, "Unnamed: 1"] == 1:
        soc_copy.drop(x, inplace=True)
soc_copy
# Out:
#     Data Notes:                        Unnamed: 1  \
# 3       Corp ID                         Corp Name
# 4          0015   Adams Central Community Schools
# 5          0025     North Adams Community Schools
# 6          0035               South Adams Schools
# 7          0125  MSD Southwest Allen County Schls
# ..          ...                               ...
# 374        9970           ACE Preparatory Academy
# 375        9975        Global Preparatory Academy
# 376        9980                Steel City Academy
# 377        9985       Seven Oaks Classical School
# 378        9990   Higher Institute of Arts & Tech
#
#                              Unnamed: 2  \
# 3    Social Studies\nBelow\nProficiency
# 4                                    38
# 5                                    29
# 6                                    32
# 7                                   160
# ..                                  ...
# 374                                  11
# ...

# %%
#Find each county's social studies scores 
soc_copy_1 = soc_copy.loc[(soc_copy['Corp Name']== 'Bartholomew Con School Corp')]
soc_copy_2 = soc_copy.loc[(soc_copy['Corp Name']== 'Flat Rock-Hawcreek School Corp')]
 

'''Attempting to write a function that will filter through the ILEARN data sets for specific counties
'''
def corps(x):
  if soc_copy.loc[x, "Corp Name"] != ('Bartholomew Con School Corp'):
        soc_copy.drop(x, inplace=True)
  return dropped

dropped_copy = corps(soc_copy)

# merge the above two df
# merged_soc = pd.concat([soc_copy_1, soc_copy_2], axis=0, join='outer', ignore_index=True)
# merged_soc
# Concatenate the DataFrames along rows (axis=0) with an outer join and ignore the index
# result =
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Corp Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 2
# ...

# %%
for x in soc_copy.index:
    if soc_copy.loc[x, "Unnamed: 1"] =! 'Bartholomew Consolidated School Corporation':
        soc_copy.drop(x, inplace=True)
soc_copy
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 2
# ...

# %%
# Renaming columns
soc_copy.rename(columns={'Data Notes:': 'Corp ID', 
                         'Unnamed: 1': 'Corp Name', 
                         'Unnamed: 2': 'Social Studies Below Proficiency', 
                         'Unnamed: 3': 'Social Studies Approaching Proficiency', 
                         'Unnamed: 4': 'Social Studies At Proficiency',
                         'Unnamed: 5': 'Social Studies Above Proficiency',
                         'Unnamed: 6': 'Social Studies Total Proficient',
                         'Unnamed: 7': 'Social Studies Total Tested',
                         'Unnamed: 8': 'Social Studies Proficient %',
                         }
                         , inplace=True)
display(soc_copy)
# Out:
#      Corp ID                         Corp Name  \
# 3    Corp ID                         Corp Name
# 4       0015   Adams Central Community Schools
# 5       0025     North Adams Community Schools
# 6       0035               South Adams Schools
# 7       0125  MSD Southwest Allen County Schls
# ..       ...                               ...
# 374     9970           ACE Preparatory Academy
# 375     9975        Global Preparatory Academy
# 376     9980                Steel City Academy
# 377     9985       Seven Oaks Classical School
# 378     9990   Higher Institute of Arts & Tech
#
#        Social Studies Below Proficiency  \
# 3    Social Studies\nBelow\nProficiency
# 4                                    38
# 5                                    29
# 6                                    32
# 7                                   160
# ..                                  ...
# 374                                  11
# 375                                  44
# ...

# %% [markdown]
# Looks like I either have to change the columns from Grade 3 to Grade 5 for consistency OR I just accept the data as is and go from there. Depends on if I need to merge/join the data.
#
# In the interest of time for this version of the project, I'm going to merge the data for Grade 3 for Math, Science, and ELA. We'll consider Social Studies separately.

# %% [markdown]
# #### Housing Data by County for the state of Indiana

# %%
# Reading in the mother file with all housing data by county

housing_data= pd.read_csv('Data_Sources\county_market_tracker_clean.zip')
housing_data.head()
# Out:
#   period_begin period_end  table_id                 region        state  \
# 0     4/1/2015  4/30/2015      2550     Bradley County, TN    Tennessee
# 1     2/1/2014  2/28/2014      1958    Dutchess County, NY     New York
# 2     6/1/2023  6/30/2023      1643        Holt County, MO     Missouri
# 3     3/1/2015  3/31/2015      1518       Adams County, MS  Mississippi
# 4     2/1/2016  2/29/2016       806  Washington County, IL     Illinois
#
#   state_code              property_type  property_type_id  median_sale_price  \
# 0         TN                Condo/Co-op                 3           199900.0
# 1         NY                  Townhouse                13           190250.0
# 2         MO  Single Family Residential                 6            75500.0
# 3         MS            All Residential                -1            94900.0
# 4         IL  Single Family Residential                 6            49000.0
#
# ...

# %%
# What are the columns? I thought I saw pricing per sqft. I need to list all the column names.
# Displaying the size and data types of our data
hdata_shape = housing_data.shape
print(f'The DataFrame has {hdata_shape[0]} rows and {hdata_shape[1]} columns! \n')
print(housing_data.info())
# Out:
# The DataFrame has 1048575 rows and 20 columns!
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   period_begin                    1048575 non-null  object
#  1   period_end                      1048575 non-null  object
#  2   table_id                        1048575 non-null  int64
#  3   region                          1048575 non-null  object
#  4   state                           1048575 non-null  object
#  5   state_code                      1048575 non-null  object
#  6   property_type                   1048575 non-null  object
#  7   property_type_id                1048575 non-null  int64
#  8   median_sale_price               1047819 non-null  float64
#  9   median_list_price               963668 non-null   float64
# ...

# %% [markdown]
# '''
# The median pricing per square foot is located in column 19.
# '''

# %%
# drop columns now that I know which columns I want
housing_data_clean = housing_data[['period_begin', 'period_end', 'region', 'state','property_type', 'median_sale_price', 'median_list_price', 'median_ppsf']]
housing_data_clean
# Out:
#         period_begin period_end                 region           state  \
# 0           4/1/2015  4/30/2015     Bradley County, TN       Tennessee
# 1           2/1/2014  2/28/2014    Dutchess County, NY        New York
# 2           6/1/2023  6/30/2023        Holt County, MO        Missouri
# 3           3/1/2015  3/31/2015       Adams County, MS     Mississippi
# 4           2/1/2016  2/29/2016  Washington County, IL        Illinois
# ...              ...        ...                    ...             ...
# 1048570     2/1/2015  2/28/2015      Apache County, AZ         Arizona
# 1048571     1/1/2021  1/31/2021     Forsyth County, NC  North Carolina
# 1048572     6/1/2022  6/30/2022       Boone County, WV   West Virginia
# 1048573     4/1/2021  4/30/2021  Livingston Parish, LA       Louisiana
# 1048574     5/1/2016  5/31/2016     Clatsop County, OR          Oregon
#
#                      property_type  median_sale_price  median_list_price  \
# ...

# %% [markdown]
# Now I need to drop the rows that do not contain Indiana as a state.

# %%
housing_data_bart = housing_data_clean.loc[housing_data_clean["region"] == "Bartholomew County, IN"]
housing_data_clark = housing_data_clean.loc[housing_data_clean["region"] == "Clark County, IN"]
housing_data_floyd = housing_data_clean.loc[housing_data_clean["region"]== "Floyd County, IN"]

display(housing_data_clark, housing_data_floyd, housing_data_bart)
# Out:
#         period_begin  period_end            region    state  \
# 643         1/1/2016   1/31/2016  Clark County, IN  Indiana
# 1796       12/1/2014  12/31/2014  Clark County, IN  Indiana
# 1842       12/1/2015  12/31/2015  Clark County, IN  Indiana
# 4393       11/1/2016  11/30/2016  Clark County, IN  Indiana
# 7871       12/1/2012  12/31/2012  Clark County, IN  Indiana
# ...              ...         ...               ...      ...
# 1036652    11/1/2024  11/30/2024  Clark County, IN  Indiana
# 1040135     2/1/2021   2/28/2021  Clark County, IN  Indiana
# 1040502     7/1/2024   7/31/2024  Clark County, IN  Indiana
# 1046036     4/1/2018   4/30/2018  Clark County, IN  Indiana
# 1048290     1/1/2015   1/31/2015  Clark County, IN  Indiana
#
#                      property_type  median_sale_price  median_list_price  \
# 643                    Condo/Co-op            95950.0                NaN
# 1796     Single Family Residential           129400.0           139950.0
# ...

# %%
#join the Three cleaned datasets together
bart_clark = housing_data_bart.merge(housing_data_clark, how = 'outer')
bart_clark

bart_clark_floyd = bart_clark.merge(housing_data_floyd, how = 'outer')
bart_clark_floyd

#drop any rows with NaN values
bart_clark_floyd = bart_clark_floyd.dropna()

# Remove State Column - that information is included in the Region column
bart_clark_floyd = bart_clark_floyd.drop(columns=['state'])

# %%
"""
Cleans and processes the Bartholomew, Clark, and Floyd County Housing DataFrame.

    This function performs the following operations on the input DataFrame:
    1. Cleans column names (capitalizes and removes underscores).

    Parameters:
        bart_clark_floyd (pandas.DataFrame): The input housing dataset.

    Returns:
        pandas.DataFrame: The cleaned and processed DataFrame.

    Example:
        >>> clean_kick_starter = clean_ks(bart_clark_floyd)\"
"""
            
def clean_hd (bart_clark_floyd) -> pd.DataFrame:

    # Clean column names
    bart_clark_floyd.columns =  bart_clark_floyd.columns.str.title()
    bart_clark_floyd.columns =  bart_clark_floyd.columns.str.strip().str.replace('_', ' ')


    return bart_clark_floyd

bart_clark_floyd_cleaned = clean_hd(bart_clark_floyd)

display(bart_clark_floyd_cleaned)
# Out:
#      Period Begin Period End                  Region  \
# 0        1/1/2012  1/31/2012  Bartholomew County, IN
# 1        1/1/2012  1/31/2012  Bartholomew County, IN
# 2        1/1/2012  1/31/2012        Clark County, IN
# 3        1/1/2012  1/31/2012        Clark County, IN
# 4        1/1/2012  1/31/2012        Floyd County, IN
# ...           ...        ...                     ...
# 1313     9/1/2024  9/30/2024        Clark County, IN
# 1314     9/1/2024  9/30/2024        Clark County, IN
# 1315     9/1/2024  9/30/2024        Floyd County, IN
# 1316     9/1/2024  9/30/2024        Floyd County, IN
# 1317     9/1/2024  9/30/2024        Floyd County, IN
#
#                   Property Type  Median Sale Price  Median List Price  \
# 0       Multi-Family (2-4 Unit)            64250.0           142900.0
# 1     Single Family Residential           125000.0           142900.0
# 2               All Residential           124250.0           141400.0
# ...

# %%
bart_clark_floyd_cleaned['Period Begin'].dtypes
# Out:
# dtype('O')

# %%
#it's an object, not datetime
#change to datetime
bart_clark_floyd_cleaned['Period Begin'] = pd.to_datetime(bart_clark_floyd_cleaned['Period Begin'], format='%m/%d/%Y')
bart_clark_floyd_cleaned
# Out:
#      Period Begin Period End                  Region  \
# 0      2012-01-01  1/31/2012  Bartholomew County, IN
# 1      2012-01-01  1/31/2012  Bartholomew County, IN
# 2      2012-01-01  1/31/2012        Clark County, IN
# 3      2012-01-01  1/31/2012        Clark County, IN
# 4      2012-01-01  1/31/2012        Floyd County, IN
# ...           ...        ...                     ...
# 1313   2024-09-01  9/30/2024        Clark County, IN
# 1314   2024-09-01  9/30/2024        Clark County, IN
# 1315   2024-09-01  9/30/2024        Floyd County, IN
# 1316   2024-09-01  9/30/2024        Floyd County, IN
# 1317   2024-09-01  9/30/2024        Floyd County, IN
#
#                   Property Type  Median Sale Price  Median List Price  \
# 0       Multi-Family (2-4 Unit)            64250.0           142900.0
# 1     Single Family Residential           125000.0           142900.0
# 2               All Residential           124250.0           141400.0
# ...

# %%
bart_clark_floyd_cleaned['Period End'] = pd.to_datetime(bart_clark_floyd_cleaned['Period End'], format='%m/%d/%Y')
bart_clark_floyd_cleaned
# Out:
#      Period Begin Period End                  Region  \
# 0      2012-01-01 2012-01-31  Bartholomew County, IN
# 1      2012-01-01 2012-01-31  Bartholomew County, IN
# 2      2012-01-01 2012-01-31        Clark County, IN
# 3      2012-01-01 2012-01-31        Clark County, IN
# 4      2012-01-01 2012-01-31        Floyd County, IN
# ...           ...        ...                     ...
# 1313   2024-09-01 2024-09-30        Clark County, IN
# 1314   2024-09-01 2024-09-30        Clark County, IN
# 1315   2024-09-01 2024-09-30        Floyd County, IN
# 1316   2024-09-01 2024-09-30        Floyd County, IN
# 1317   2024-09-01 2024-09-30        Floyd County, IN
#
#                   Property Type  Median Sale Price  Median List Price  \
# 0       Multi-Family (2-4 Unit)            64250.0           142900.0
# 1     Single Family Residential           125000.0           142900.0
# 2               All Residential           124250.0           141400.0
# ...

# %%
average_marks = bart_clark_floyd_cleaned.groupby('Region')['Median Sale Price'].mean()
print(average_marks)
# Out:
# Region
# Bartholomew County, IN    177032.240139
# Clark County, IN          171627.334135
# Floyd County, IN          175899.410959
# Name: Median Sale Price, dtype: float64

# %%
"""
Cleans and processes the Bartholomew, Clark, and Floyd County Housing DataFrame.

    This function performs the following operations on the input DataFrame:
    1. Cleans column names (capitalizes and removes underscores).

    Parameters:
        bart_clark_floyd (pandas.DataFrame): The input housing dataset.

    Returns:
        pandas.DataFrame: The cleaned and processed DataFrame.

    Example:
        >>> clean_kick_starter = clean_ks(bart_clark_floyd)\"
"""
            
def clean_hd (bart_clark_floyd) -> pd.DataFrame:

    # Clean column names
    bart_clark_floyd.columns =  bart_clark_floyd.columns.str.title()
    bart_clark_floyd.columns =  bart_clark_floyd.columns.str.strip().str.replace('_', ' ')


    return bart_clark_floyd

bart_clark_floyd_cleaned = clean_hd(bart_clark_floyd)

display(bart_clark_floyd_cleaned)
# Out:
#      Period Begin Period End                  Region  \
# 0        1/1/2012  1/31/2012  Bartholomew County, IN
# 1        1/1/2012  1/31/2012  Bartholomew County, IN
# 2        1/1/2012  1/31/2012        Clark County, IN
# 3        1/1/2012  1/31/2012        Clark County, IN
# 4        1/1/2012  1/31/2012        Floyd County, IN
# ...           ...        ...                     ...
# 1313     9/1/2024  9/30/2024        Clark County, IN
# 1314     9/1/2024  9/30/2024        Clark County, IN
# 1315     9/1/2024  9/30/2024        Floyd County, IN
# 1316     9/1/2024  9/30/2024        Floyd County, IN
# 1317     9/1/2024  9/30/2024        Floyd County, IN
#
#                   Property Type  Median Sale Price  Median List Price  \
# 0       Multi-Family (2-4 Unit)            64250.0           142900.0
# 1     Single Family Residential           125000.0           142900.0
# 2               All Residential           124250.0           141400.0
# ...

# %% [markdown]
# I need more recent data - housing data from 10+ years ago will not help me understand if I can afford a house in that region now. Preferably, I would like data from the last rolling 12 months to get a clearer picture of housing prices in these regions.

# %%
# renaming bart_clark_floyd_cleaned, because it's long and clunky
bcf_cleaned = bart_clark_floyd_cleaned

bcf_cleaned['Year'] = pd.DatetimeIndex(bcf_cleaned['Period End']).year
bcf_cleaned['Month'] = pd.DatetimeIndex(bcf_cleaned['Period End']).month

# Filter data between two dates
filtered_bcf = bcf_cleaned.loc[(bcf_cleaned['Period Begin'] >= '2024-02-01')]   



filtered_bcf
# Out:
#      Period Begin Period End                  Region  \
# 100    2025-01-01 2025-01-31  Bartholomew County, IN
# 101    2025-01-01 2025-01-31  Bartholomew County, IN
# 102    2025-01-01 2025-01-31  Bartholomew County, IN
# 103    2025-01-01 2025-01-31        Clark County, IN
# 105    2025-01-01 2025-01-31        Clark County, IN
# ...           ...        ...                     ...
# 1313   2024-09-01 2024-09-30        Clark County, IN
# 1314   2024-09-01 2024-09-30        Clark County, IN
# 1315   2024-09-01 2024-09-30        Floyd County, IN
# 1316   2024-09-01 2024-09-30        Floyd County, IN
# 1317   2024-09-01 2024-09-30        Floyd County, IN
#
#                   Property Type  Median Sale Price  Median List Price  \
# 100             All Residential           232500.0           299900.0
# 101     Multi-Family (2-4 Unit)           321500.0           299900.0
# 102   Single Family Residential           231250.0           299900.0
# ...

# %%
counties = filtered_bcf.groupby('Region')
#filtered_bcf.groupby('Region'['Bartholomew County, IN']).mean()

# %%
for mean_counties, group in counties:
    group_mean = group.mean(axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 2
#       1 for mean_counties, group in counties:
# ----> 2     group_mean = group.mean(axis=0)
#
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
# ...

# %%
# filtered_bcf['Year'] = pd.DatetimeIndex(filtered_bcf['Period End']).year
# filtered_bcf['Month'] = pd.DatetimeIndex(filtered_bcf['Period End']).month

filtered_bcf.dtypes
# Out:
# Period Begin         datetime64[ns]
# Period End           datetime64[ns]
# Region                       object
# Property Type                object
# Median Sale Price           float64
# Median List Price           float64
# Median Ppsf                 float64
# Year                          int32
# Month                         int32
# dtype: object

# %%
filtered_bcf_sansdt = filtered_bcf.drop(columns=['Period End'])
filtered_bcf_sansdt
# Out:
#      Period Begin                  Region              Property Type  \
# 100    2025-01-01  Bartholomew County, IN            All Residential
# 101    2025-01-01  Bartholomew County, IN    Multi-Family (2-4 Unit)
# 102    2025-01-01  Bartholomew County, IN  Single Family Residential
# 103    2025-01-01        Clark County, IN            All Residential
# 105    2025-01-01        Clark County, IN  Single Family Residential
# ...           ...                     ...                        ...
# 1313   2024-09-01        Clark County, IN  Single Family Residential
# 1314   2024-09-01        Clark County, IN                  Townhouse
# 1315   2024-09-01        Floyd County, IN            All Residential
# 1316   2024-09-01        Floyd County, IN                Condo/Co-op
# 1317   2024-09-01        Floyd County, IN  Single Family Residential
#
#       Median Sale Price  Median List Price  Median Ppsf  Year  Month
# 100            232500.0           299900.0   134.245187  2025      1
# ...

# %%
filtered_bcf_sansdt.dtypes
# Out:
# Period Begin         datetime64[ns]
# Region                       object
# Property Type                object
# Median Sale Price           float64
# Median List Price           float64
# Median Ppsf                 float64
# Year                          int32
# Month                         int32
# dtype: object

# %%
# Create a bar graph
fig = px.bar(filtered_bcf_sansdt, x='Period Begin', y='Median Sale Price', color='Region', barmode='group',
             title='Median Sale Prices for the last rolling 12 months',
             labels={'Median Sale Price': 'Median Home Price ($)', 'Date': 'Period Begin'},
             height=400)

fig.show()

# %%
dcc.Graph(
    figure={
        'data': [
            {'x': [1, 2, 3], 'y': [4, 1, 2], 'type': 'bar', 'name': 'SF'},
            {'x': [1, 2, 3], 'y': [2, 4, 5], 'type': 'bar', 'name': 'Montréal'},
        ],
        'layout': {
            'title': 'Dash Data Visualization'
        }
    }
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 from dash import dcc
#       3 dcc.Graph(
#       4     figure={
#       5         'data': [
#    (...)
#      12     }
#      13 )
#
# ModuleNotFoundError: No module named 'dash'

# %%
# Basic correlogram
sns.pairplot(filtered_bcf_sansdt)
plt.show()

# %%
# perform groupby 
# filtered_bcf = filtered_bcf.groupby(['Year', 'Region']).agg(median_sales=("Median Sale Price", 'median')) 
# filtered_bcf = filtered_bcf.reset_index() 
  
# plot barplot 
px.barplot(x="Month", 
           y="median sales", 
           hue="deep", 
           data=filtered_bcf_sansdt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 6
#       1 # perform groupby
#       2 # filtered_bcf = filtered_bcf.groupby(['Year', 'Region']).agg(median_sales=("Median Sale Price", 'median'))
#       3 # filtered_bcf = filtered_bcf.reset_index()
#       4
#       5 # plot barplot
# ----> 6 sns.barplot(x="Month",
#       7            y="median sales",
#       8            hue="deep",
#       9            data=filtered_bcf_sansdt)
#
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
# ...

# %%
filtered_bcf.boxplot(x='Region', y='Median Sale Price')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 filtered_bcf.boxplot(x='Region', y='Median Sale Price')
#
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\plotting\_core.py:533, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)
#     530     **kwargs,
#     531 ):
#     532     plot_backend = _get_plot_backend(backend)
# --> 533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#     536         by=by,
#     537         ax=ax,
#     538         fontsize=fontsize,
#     539         rot=rot,
#     540         grid=grid,
# ...

# %%
#Gorgeous  - cAN i CHANGE THE COLOR BY REGION???

# %%
# Step 1: Extract Data
# Replace these with your actual DataFrame columns
region = filtered_bcf['Region']
median_sale = filtered_bcf['Median Sale Price']

# Step 2: Create the Plot
plt.figure(figsize=(10, 6))  # Set figure size
plt.bar(region, median_sale, color='skyblue')  # Create a line plot

# Step 3: Rotate x-axis labels
plt.xticks(rotation=90)

# Step 4: Add Title and Labels
plt.title('Median Sale Prices in Clark, Floyd, and Bartholomew Counties')  # Title of the plot
plt.xlabel('Region')  # Label for x-axis
plt.ylabel('Median sale Price')  # Label for y-axis

# Step 5: Optional - Add Gridlines
# Uncomment the following line if you want to add gridlines
# plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7)

# Step 6: Adjust Layout
plt.tight_layout()  # Adjust layout to avoid overlap

# Step 7: Show the Plot
plt.show()

# %%
#visualize the data
filtered_bcf.plot()
# Out:
# <Axes: >

# %% [markdown]
# That makes no sense. I need to move the Region column and then transpose it with the dates.

# %%
transposed_bcf = filtered_bcf.transpose()
display(transposed_bcf)
# Out:
#                                      100                     101   \
# Period Begin          2025-01-01 00:00:00     2025-01-01 00:00:00
# Period End            2025-01-31 00:00:00     2025-01-31 00:00:00
# Region             Bartholomew County, IN  Bartholomew County, IN
# Median Sale Price                231250.0                232500.0
# Median List Price                299900.0                299900.0
# Median Ppsf                     136.03285              134.245187
#
#                                      102                  104   \
# Period Begin          2025-01-01 00:00:00  2025-01-01 00:00:00
# Period End            2025-01-31 00:00:00  2025-01-31 00:00:00
# Region             Bartholomew County, IN     Clark County, IN
# Median Sale Price                321500.0             247500.0
# Median List Price                299900.0             274900.0
# Median Ppsf                     53.798527           145.509943
#
# ...

# %%
transposed_bcf.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 transposed_bcf.plot()
#
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %% [markdown]
# Why is there no numeric data to plot???

# %%
#adjust so top row of data becomes column headers 
# bcf_transposed.rename(columns=bcf_transposed.iloc[0]).drop(bcf_transposed.index[0])

transposed_bcf.rename(columns=transposed_bcf.iloc[0]).drop(transposed_bcf.index[0])
# Out:
# c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\core\indexes\base.py:7631: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(index_like, name=name, copy=copy)
#                                2025-01-01              2025-01-01  \
# Period End            2025-01-31 00:00:00     2025-01-31 00:00:00
# Region             Bartholomew County, IN  Bartholomew County, IN
# Median Sale Price                231250.0                232500.0
# Median List Price                299900.0                299900.0
# Median Ppsf                     136.03285              134.245187
#
#                                2025-01-01           2025-01-01  \
# Period End            2025-01-31 00:00:00  2025-01-31 00:00:00
# ...

# %%
# bcf_transposed.plot(kind='bar')
# get an error when I try to plot - verify datatypes

transposed_bcf.dtypes
# Out:
# 100     object
# 101     object
# 102     object
# 104     object
# 105     object
#          ...
# 1313    object
# 1314    object
# 1315    object
# 1316    object
# 1317    object
# Length: 103, dtype: object

# %%
# they're objects, not integers. Need to change the 1,000+ columns to integers.
# df['col_name'] = pd.to_numeric(df['col_name']) will chance a specific column, but I cannot write out each column name, no one has time for that.  
# always grateful for Stack Overlow - for loop to change datatypes in multiple columns based on the column type
for column in transposed_bcf.columns:
    if transposed_bcf[column].dtype == 'object':
        transposed_bcf[column] = transposed_bcf[column].astype(str)

# unless the datatype cannot be confirmed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 4
#       1 # they're objects, not integers. Need to change the 1,000+ columns to integers.
#       2 # df['col_name'] = pd.to_numeric(df['col_name']) will chance a specific column, but I cannot write out each column name, no one has time for that.
#       3 # always grateful for Stack Overlow - for loop to change datatypes in multiple columns based on the column type
# ----> 4 for column in transposed_bcf.columns:
#       5     if transposed_bcf[column].dtype == 'object':
#       6         transposed_bcf[column] = transposed_bcf[column].astype(str)
#
# NameError: name 'transposed_bcf' is not defined

# %%
def summarize_housing_data(bart_clark_floyd_cleaned: DataFrame) -> str:
    """
    Calculates and summarizes the total, mean, and median number of backers 
    from a Housing dataset.

    Parameters:
        bart_clark_floyd_cleaned (pandas.DataFrame): The housing dataset containing a 
                                         'Median Sale Price' column.

    Returns:
        str: A formatted string summarizing the total, mean (rounded to 2 decimal places),
             and median number of backers.
    """
    # Calculate total, mean, and median backers
    sales_min = bart_clark_floyd_cleaned['Median Sale Price'].min()
    sales_mean = bart_clark_floyd_cleaned['Median Sale Price'].mean().round(2)
    sales_median = bart_clark_floyd_cleaned['Median Sale Price'].median()
    sales_max = bart_clark_floyd_cleaned['Median Sale Price'].max()

    # Return a formatted string
    return (f"The mean sales price is {sales_mean}.\n"
            f"The median sales price is {sales_median}.\n"
            f"The min sales price is {sales_min}.\n"
            f"The max sales price is {sales_max}")

sales_summed = summarize_housing_data(bart_clark_floyd_cleaned)
print(sales_summed)
# Out:
# The mean sales price is 174835.93.
# The median sales price is 165000.0.
# The min sales price is 1575.0.
# The max sales price is 600000.0

# %% [markdown]
# The minimum sales price seems really low. I want to plot the three median sales prices from each county so I can better visualize the listing price patterns in each county.

# %%
transposed_bcf.plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 transposed_bcf.plot(kind = 'bar')
#
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\rache\OneDrive\Documents\Projects\Capstone_Project\SoIN_Housing_Analysis\venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
def summarize_ppsf(bart_clark_floyd_cleaned: DataFrame) -> str:
    """
    Calculates and summarizes the mean and median pricing per squarefoot 
    from a Housing dataset.

    Parameters:
        bart_clark_floyd_cleaned (pandas.DataFrame): The housing dataset containing a 
                                         'Median Ppsf' column.

    Returns:
        str: A formatted string summarizing the mean (rounded to 2 decimal places)
             and median price per square foot of listed houses. 
    """
    # Calculate total, mean, and median backers
    ppsf_mean = bart_clark_floyd_cleaned['Median Ppsf'].mean().round(2)
    ppsf_median = bart_clark_floyd_cleaned['Median Ppsf'].median()

    # Return a formatted string
    return (f"The mean price per square foot is {ppsf_mean}.\n"
            f"The median price per square foot is {ppsf_median}.")

ppsf_summed = summarize_ppsf(bart_clark_floyd_cleaned)
print(ppsf_summed)
# Out:
# The mean price per square foot is 104.56.
# The median price per square foot is 96.800404875.

# %% [markdown]
# I now have the average price per square foot of 104.56. Let's do some math to find out what the price should be of a 2,000 square foot house.

# %%
ppsf_mean = bart_clark_floyd_cleaned['Median Ppsf'].mean().round(2)
x = ppsf_mean 
twothou = x * 2000

print(twothou)
# Out:
# 209120.0

# %% [markdown]
# According to this, the average 2,000 square foot house is $209,120.00. My data isn't showing this, but anecdotally, from personal surveys of various realtor websites (like Zillow or Redfin) I know that is NOT the price of houses that are 2,000 sqft in the Clark and Floyd counties. I've realized I'm likely not controlling for types of sales or housing - I'm assuming this is for single family homes but it doesn't say that anywhere in the dataset.
#
#
# I went back to my data source - [Redfin's Data Center](https://www.redfin.com/news/data-center/). There I found a different dataset that included the Monthly Housing Data for the past 12 years, and I was able to control for property type to single family homes. There's not a clear way to control for any sales that were by auction, but I can at least be assured the median sales price and price per square foot are for single family homes.

# %%
median_sale = pd.read_csv('Data_Sources\med_sale_price.csv')
median_sale.head()
# Out:
#                Unnamed: 0 Month of Period End Month of Period End.1  \
# 0                  Region              Jan-12                Feb-12
# 1  Bartholomew County, IN               $125K                 $109K
# 2        Clark County, IN               $122K                 $127K
# 3        Floyd County, IN               $140K                 $120K
#
#   Month of Period End.2 Month of Period End.3 Month of Period End.4  \
# 0                Mar-12                Apr-12                May-12
# 1                 $134K                 $131K                 $136K
# 2                 $122K                 $117K                 $130K
# 3                 $117K                 $107K                 $162K
#
#   Month of Period End.5 Month of Period End.6 Month of Period End.7  \
# 0                Jun-12                Jul-12                Aug-12
# 1                 $150K                 $128K                 $150K
# 2                 $116K                 $123K                 $124K
# ...
