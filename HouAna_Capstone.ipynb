# %%
#Import necessary libraries and such for project. And some extra stuff, just in case.
import pandas as pd
import matplotlib
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
#read in the data for median square footage by county starting with Bartholomew County, IN 

bartco_sqft = pd.read_csv('Data_Sources\med_sqft_bartco.csv')

#verify data reads in and print the first five rows)
bartco_sqft.head()
# Out:
#    Day of Year  Year of Period End Period Begin Period End  \
# 0            1                2023    12/5/2022   1/1/2023
# 1            2                2022    12/6/2021   1/2/2022
# 2            5                2025    12/9/2024   1/5/2025
# 3            7                2024   12/11/2023   1/7/2024
# 4            8                2023   12/12/2022   1/8/2023
#
#   Median Pending Sqft Yoy (tooltip) Median Pending Sqft Yoy  \
# 0                           -10.90%                    -11%
# 1                             8.30%                      8%
# 2                             9.90%                     10%
# 3                           -18.80%                    -19%
# 4                             5.90%                      6%
#
#   Median Pending Sqft
# 0            1,802.10
# 1               2,023
# 2            1,771.70
# 3            1,612.10
# 4            1,986.10

# %%
#read in the data for median square footage by county - Floyd County, IN

floco_sqft = pd.read_csv('Data_Sources\med_sqft_floco.csv')

#verify data reads in and print the first five rows)
floco_sqft.head()
# Out:
#    Day of Year  Year of Period End Period Begin Period End  \
# 0            1                2023    12/5/2022   1/1/2023
# 1            2                2022    12/6/2021   1/2/2022
# 2            5                2025    12/9/2024   1/5/2025
# 3            7                2024   12/11/2023   1/7/2024
# 4            8                2023   12/12/2022   1/8/2023
#
#   Median Pending Sqft Yoy (tooltip) Median Pending Sqft Yoy  \
# 0                           -22.00%                    -22%
# 1                             8.50%                      9%
# 2                           -13.00%                    -13%
# 3                            23.70%                     24%
# 4                           -15.50%                    -16%
#
#   Median Pending Sqft
# 0            1,535.70
# 1            1,969.80
# 2            1,742.20
# 3            2,002.70
# 4            1,619.50

# %%
#read in the data for median square footage by county - Clark County, IN

claco_sqft = pd.read_csv('Data_Sources\med_sqft_claco.csv')

#verify data reads in and print the first five rows)
claco_sqft.head()
# Out:
#    Day of Year  Year of Period End Period Begin Period End  \
# 0            1                2023    12/5/2022   1/1/2023
# 1            2                2022    12/6/2021   1/2/2022
# 2            5                2025    12/9/2024   1/5/2025
# 3            7                2024   12/11/2023   1/7/2024
# 4            8                2023   12/12/2022   1/8/2023
#
#   Median Pending Sqft Yoy (tooltip) Median Pending Sqft Yoy  \
# 0                             9.00%                      9%
# 1                             6.30%                      6%
# 2                             3.30%                      3%
# 3                            -7.30%                     -7%
# 4                            -1.90%                     -2%
#
#   Median Pending Sqft
# 0               1,771
# 1            1,625.10
# 2               1,526
# 3            1,477.30
# 4            1,593.70

# %%
#read in the data for median listed housing prices by county - Clark County, IN

claco_price = pd.read_csv('Data_Sources\med_price_clark.csv')

#verify data reads in and print the first five rows)
claco_price.head()
# Out:
#    Day of Year    Last Updated  Year of Period End Period Begin Period End  \
# 0            1  2/5/2025 14:47                2023    12/5/2022   1/1/2023
# 1            2  2/5/2025 14:47                2022    12/6/2021   1/2/2022
# 2            5  2/5/2025 14:47                2025    12/9/2024   1/5/2025
# 3            7  2/5/2025 14:47                2024   12/11/2023   1/7/2024
# 4            8  2/5/2025 14:47                2023   12/12/2022   1/8/2023
#
#   Median Sale Price Yoy (tooltip)  Median Sale Price Yoy Median Sale Price
# 0                           2.94%               0.029364        229,023.70
# 1                          13.41%               0.134071        222,490.50
# 2                          -3.95%              -0.039493           227,735
# 3                           0.50%               0.004980        237,098.70
# 4                           7.42%               0.074197        235,923.70

# %%
#read in the data for median listed housing prices by county - Floyd County, IN
floco_price = pd.read_csv('Data_Sources\med_price_floco.csv')

#verify data reads in and print the first five rows)
floco_price.head()
# Out:
#    Day of Year     Last Updated  Year of Period End Period Begin Period End  \
# 0            1  2/12/2025 14:46                2023    12/5/2022   1/1/2023
# 1            2  2/12/2025 14:46                2022    12/6/2021   1/2/2022
# 2            5  2/12/2025 14:46                2025    12/9/2024   1/5/2025
# 3            7  2/12/2025 14:46                2024   12/11/2023   1/7/2024
# 4            8  2/12/2025 14:46                2023   12/12/2022   1/8/2023
#
#   Median Sale Price Yoy (tooltip)  Median Sale Price Yoy Median Sale Price
# 0                         -10.69%              -0.106938           219,950
# 1                          21.05%               0.210519        246,287.50
# 2                          33.33%               0.333254        315,981.20
# 3                          -2.18%              -0.021823           237,000
# 4                           3.50%               0.035030        242,287.50

# %%
#read in the data for median listed housing prices by county - Bartholomew County, IN
bartco_price = pd.read_csv('Data_Sources\med_price_bartco.csv')

#verify data reads in and print the first five rows)
bartco_price.head()
# Out:
#    Day of Year     Last Updated  Year of Period End Period Begin Period End  \
# 0            1  2/12/2025 14:46                2023    12/5/2022   1/1/2023
# 1            2  2/12/2025 14:46                2022    12/6/2021   1/2/2022
# 2            5  2/12/2025 14:46                2025    12/9/2024   1/5/2025
# 3            7  2/12/2025 14:46                2024   12/11/2023   1/7/2024
# 4            8  2/12/2025 14:46                2023   12/12/2022   1/8/2023
#
#   Median Sale Price Yoy (tooltip)  Median Sale Price Yoy Median Sale Price
# 0                          -2.89%              -0.028948        227,687.50
# 1                          14.94%               0.149387           234,475
# 2                          -1.58%              -0.015849        247,562.50
# 3                           5.84%               0.058375        251,549.30
# 4                           3.29%               0.032920           237,675

# %%
#read in the data for ILEARN 2024 test scores for all school coporations in Indiana - ELA section
ilearn_ELA_corp = pd.read_csv('Data_Sources\ILEARN_Corp_ELA.csv')

#verify data reads in and print the first five rows)
ilearn_ELA_corp.head()
# Out:
#                                          Data Notes:  \
# 0      Scores reflect all ILEARN Spring 2024 testers
# 1  *** - Indicates less than 10 students in group...
# 2                                                NaN
# 3                                            Corp ID
# 4                                               0015
#
#                         Unnamed: 1               Unnamed: 2  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                  Grade 3
# 3                        Corp Name  ELA\nBelow\nProficiency
# 4  Adams Central Community Schools                       35
#
#                        Unnamed: 3             Unnamed: 4  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3  ELA \nApproaching\nProficiency  ELA \nAt\nProficiency
# 4                              21                     24
#
#                  Unnamed: 5              Unnamed: 6          Unnamed: 7  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3  ELA \nAbove\nProficiency  ELA\nTotal\nProficient  ELA\nTotal\nTested
# 4                         9                      33                  89
#
#             Unnamed: 8               Unnamed: 9  ...         Unnamed: 42  \
# 0                  NaN                      NaN  ...                 NaN
# 1                  NaN                      NaN  ...                 NaN
# 2                  NaN                  Grade 4  ...                 NaN
# 3  ELA\nProficient \n%  ELA\nBelow\nProficiency  ...  ELA\nTotal\nTested
# 4                37.1%                       27  ...                  99
#
#            Unnamed: 43              Unnamed: 44  \
# 0                  NaN                      NaN
# 1                  NaN                      NaN
# 2                  NaN        Corporation Total
# 3  ELA\nProficient \n%  ELA\nBelow\nProficiency
# 4                53.5%                      168
#
#                       Unnamed: 45            Unnamed: 46  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3  ELA \nApproaching\nProficiency  ELA \nAt\nProficiency
# 4                             139                    180
#
#                 Unnamed: 47             Unnamed: 48         Unnamed: 49  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3  ELA \nAbove\nProficiency  ELA\nTotal\nProficient  ELA\nTotal\nTested
# 4                       108                     288                 595
#
#            Unnamed: 50 Unnamed: 51
# 0                  NaN         NaN
# 1                  NaN         NaN
# 2                  NaN         NaN
# 3  ELA\nProficient \n%         NaN
# 4                48.4%         NaN
#
# [5 rows x 52 columns]

# %%
# Reading in the mother file with all housing data by county
housing_data = pd.read_csv('Data_Sources\county_market_tracker.tsv000', sep='\t')

housing_data.head()
# Out:
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2015-04-01  2015-04-30               30      county               5
# 1   2014-02-01  2014-02-28               30      county               5
# 2   2023-06-01  2023-06-30               30      county               5
# 3   2015-03-01  2015-03-31               30      county               5
# 4   2016-02-01  2016-02-29               30      county               5
#
#    table_id is_seasonally_adjusted                 region  city        state  \
# 0      2550                      f     Bradley County, TN   NaN    Tennessee
# 1      1958                      f    Dutchess County, NY   NaN     New York
# 2      1643                      f        Holt County, MO   NaN     Missouri
# 3      1518                      f       Adams County, MS   NaN  Mississippi
# 4       806                      f  Washington County, IL   NaN     Illinois
#
#    ... sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# 0  ...                 NaN         NaN              NaN              NaN
# 1  ...            0.000000         NaN              NaN              NaN
# 2  ...           -0.333333    0.307692         0.141026              NaN
# 3  ...            0.181818         NaN              NaN              NaN
# 4  ...            0.400000         NaN              NaN              NaN
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                      0.0                          NaN
# 1                      0.0                          0.0
# 2                      NaN                          NaN
# 3                      0.0                          0.0
# 4                      0.0                          0.0
#
#    off_market_in_two_weeks_yoy            parent_metro_region  \
# 0                          NaN                  Cleveland, TN
# 1                          0.0               Poughkeepsie, NY
# 2                          NaN  Missouri nonmetropolitan area
# 3                          0.0                    Natchez, MS
# 4                          0.0  Illinois nonmetropolitan area
#
#    parent_metro_region_metro_code         last_updated
# 0                         17420.0  2025-02-10 14:21:52
# 1                         39100.0  2025-02-10 14:21:52
# 2                             NaN  2025-02-10 14:21:52
# 3                         35020.0  2025-02-10 14:21:52
# 4                             NaN  2025-02-10 14:21:52
#
# [5 rows x 58 columns]

# %%
# What are the columns? I thought I saw pricing per sqft. I need to list all the column names.
# Displaying the size and data types of our data
hdata_shape = housing_data.shape
print(f'The DataFrame has {hdata_shape[0]} rows and {hdata_shape[1]} columns! \n')
print(housing_data.info())
# Out:
# The DataFrame has 1208726 rows and 58 columns!
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1208726 entries, 0 to 1208725
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   period_begin                    1208726 non-null  object
#  1   period_end                      1208726 non-null  object
#  2   period_duration                 1208726 non-null  int64
#  3   region_type                     1208726 non-null  object
#  4   region_type_id                  1208726 non-null  int64
#  5   table_id                        1208726 non-null  int64
#  6   is_seasonally_adjusted          1208726 non-null  object
#  7   region                          1208726 non-null  object
#  8   city                            0 non-null        float64
#  9   state                           1208726 non-null  object
#  10  state_code                      1208726 non-null  object
#  11  property_type                   1208726 non-null  object
#  12  property_type_id                1208726 non-null  int64
#  13  median_sale_price               1207708 non-null  float64
#  14  median_sale_price_mom           1088894 non-null  float64
#  15  median_sale_price_yoy           1058296 non-null  float64
#  16  median_list_price               1110721 non-null  float64
#  17  median_list_price_mom           1022663 non-null  float64
#  18  median_list_price_yoy           991936 non-null   float64
#  19  median_ppsf                     1196024 non-null  float64
#  20  median_ppsf_mom                 1078688 non-null  float64
#  21  median_ppsf_yoy                 1048043 non-null  float64
#  22  median_list_ppsf                1109384 non-null  float64
#  23  median_list_ppsf_mom            1021205 non-null  float64
#  24  median_list_ppsf_yoy            990412 non-null   float64
#  25  homes_sold                      1207730 non-null  float64
#  26  homes_sold_mom                  1088920 non-null  float64
#  27  homes_sold_yoy                  1058318 non-null  float64
#  28  pending_sales                   1153153 non-null  float64
#  29  pending_sales_mom               1046064 non-null  float64
#  30  pending_sales_yoy               1014868 non-null  float64
#  31  new_listings                    1106035 non-null  float64
#  32  new_listings_mom                1018260 non-null  float64
#  33  new_listings_yoy                987257 non-null   float64
#  34  inventory                       1164094 non-null  float64
#  35  inventory_mom                   1066095 non-null  float64
#  36  inventory_yoy                   1031661 non-null  float64
#  37  months_of_supply                1177579 non-null  float64
#  38  months_of_supply_mom            1078993 non-null  float64
#  39  months_of_supply_yoy            1045431 non-null  float64
#  40  median_dom                      1197265 non-null  float64
#  41  median_dom_mom                  1078508 non-null  float64
#  42  median_dom_yoy                  1047271 non-null  float64
#  43  avg_sale_to_list                1115079 non-null  float64
#  44  avg_sale_to_list_mom            1002595 non-null  float64
#  45  avg_sale_to_list_yoy            975578 non-null   float64
#  46  sold_above_list                 1201465 non-null  float64
#  47  sold_above_list_mom             1082938 non-null  float64
#  48  sold_above_list_yoy             1052271 non-null  float64
#  49  price_drops                     581654 non-null   float64
#  50  price_drops_mom                 529828 non-null   float64
#  51  price_drops_yoy                 461129 non-null   float64
#  52  off_market_in_two_weeks         1172079 non-null  float64
#  53  off_market_in_two_weeks_mom     1063799 non-null  float64
#  54  off_market_in_two_weeks_yoy     1031662 non-null  float64
#  55  parent_metro_region             1208408 non-null  object
#  56  parent_metro_region_metro_code  868682 non-null   float64
#  57  last_updated                    1208726 non-null  object
# dtypes: float64(44), int64(4), object(10)
# memory usage: 534.9+ MB
# None

# %% [markdown]
# '''
# The median pricing per square foot is located in column 19.
# '''
